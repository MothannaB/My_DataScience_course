# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
s = pd.Series([1, 2, 2.5, 3, 3.5, 4, 5,5,5,5])
ax = s.plot.kde()

# %%
r = [27037,1542 ,1216, 1173 ,1065, 737, 725 ,528, 156, 66, 27, 16, 3, 3, 2, 2, 1]
s2 = pd.Series(r)
ax2 = s2.plot.kde()

# %%
r4 = [27037,1542 ,1216, 1173 ,1065, 737, 725 ,528,276]
s3 = pd.Series(r4)
ax22 = s3.plot.kde()
