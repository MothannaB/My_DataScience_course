# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys

# %%
fig, axes = plt.subplots() 
# fig.axes[0].yaxis.get_major_ticks()[0].get_pad()
axes = fig.axes[0] 
axes.set_title("my_g")
axes.get_title()
# Out:
# 'my_g'

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(1, rng.size))
yrs = 1950 + rng

# %%
yrs[40]
# Out:
# 1990

# %%
rng[40]
# Out:
# 40

# %%
rnd[0][40]
# Out:
# 6

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(yrs, rnd[0]+rng)
ax.set_title("my_graph")
ax.set_xlabel("year")
ax.set_ylabel("price")
ax.set_xlim(xmin=1950, xmax=1990)
ax.set_ylim(ymin=10, ymax=40)
fig.tight_layout()

# %%
figure2, axes2 = plt.subplots(nrows=2, ncols=2, figsize=(7,7))
ax10, ax2, ax3, ax4 = axes2.flatten()
ax10.plot([1,2,3], [4,3,1])
ax2.plot([1,2,3], [44,3,1])
ax3.plot([1,2,3], [4,31,1])
ax4.plot([1,2,3], [4,3,16])

print(id(figure2)
,id(plt.gcf()))

plt.get_fignums()
# Out:
# 2278069619464 2278069619464
# [1]

# %%
fi, a = plt.subplots()
plt.figure(1)
plt.close(1)
plt.figure(1)

5==3
# Out:
# False

# %%
np.inf
# Out:
# inf
